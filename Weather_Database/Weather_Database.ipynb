# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 771

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

 
      

        
        
        print(city_lat, city_lng, city_max_temp, city_humidity, city_clouds, city_wind, city_country, city_weather_description )   
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description":city_weather_description})
                        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# -22.9661 -42.0278 71.46 78 100 9.22 BR overcast clouds
# Processing Record 2 of Set 1 | chaman
# 30.9236 66.4512 68.9 12 0 5.32 PK clear sky
# Processing Record 3 of Set 1 | tasiilaq
# 65.6145 -37.6368 32.16 62 72 5.26 GL broken clouds
# Processing Record 4 of Set 1 | mataura
# -46.1927 168.8643 39.47 89 100 8.08 NZ overcast clouds
# Processing Record 5 of Set 1 | rikitea
# -23.1203 -134.9692 69.01 64 0 22.28 PF clear sky
# Processing Record 6 of Set 1 | longyearbyen
# 78.2186 15.6401 40.84 70 40 13.8 SJ scattered clouds
# Processing Record 7 of Set 1 | punta arenas
# -53.15 -70.9167 53.71 43 75 14.97 CL broken clouds
# Processing Record 8 of Set 1 | sao francisco
# -15.9486 -44.8644 90.16 35 58 4.72 BR light rain
# Processing Record 9 of Set 1 | paris
# 48.8534 2.3488 61.77 86 100 10.36 FR overcast clouds
# Processing Record 10 of Set 1 | laredo
# 27.5064 -99.5075 84.49 48 100 3.44 US overcast clouds
# Processing Record 11 of Set 1 | requena
# 39.4883 -1.1004 62.8 92 24 5.37 ES few clouds
# Processing Record 12 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 13 of Set 1 | kavaratti
# 10.5669 72.642 81.19 79 78 15.39 IN broken clouds
# Processing Record 14 of Set 1 | vanavara
# 60.34 102.2797 26.6 83 38 3.51 RU scattered clouds
# Processing Record 15 of Set 1 | sampit
# -2.5333 112.95 73.63 98 100 1.01 ID overcast clouds
# Processing Record 16 of Set 1 | lebu
# -37.6167 -73.65 54.59 69 100 9.84 CL overcast clouds
# Processing Record 17 of Set 1 | port alfred
# -33.5906 26.891 61.18 90 93 3 ZA overcast clouds
# Processing Record 18 of Set 1 | qaanaaq
# 77.484 -69.3632 6.98 73 50 7.72 GL scattered clouds
# Processing Record 19 of Set 1 | bluff
# -46.6 168.3333 39.79 69 94 22.03 NZ overcast clouds
# Processing Record 20 of Set 1 | ponta do sol
# 32.6667 -17.1 72.72 89 100 5.95 PT overcast clouds
# Processing Record 21 of Set 1 | atuona
# -9.8 -139.0333 77.31 71 1 14.99 PF clear sky
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | anito
# 12.4497 125.2886 78.8 85 100 3.94 PH overcast clouds
# Processing Record 24 of Set 1 | tuktoyaktuk
# 69.4541 -133.0374 32 100 100 10.36 CA overcast clouds
# Processing Record 25 of Set 1 | kaka
# 37.3482 59.6143 61.93 13 0 6.78 TM clear sky
# Processing Record 26 of Set 1 | talnakh
# 69.4865 88.3972 23.49 93 87 3.38 RU overcast clouds
# Processing Record 27 of Set 1 | abha
# 18.2164 42.5053 71.42 21 20 9.22 SA few clouds
# Processing Record 28 of Set 1 | fortuna
# 40.5982 -124.1573 68.94 71 7 3 US clear sky
# Processing Record 29 of Set 1 | hithadhoo
# -0.6 73.0833 82.27 74 100 18.43 MV overcast clouds
# Processing Record 30 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 31 of Set 1 | mantua
# 45.1667 10.7833 66.09 85 44 0.98 IT scattered clouds
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | vao
# -22.6667 167.4833 70.48 56 99 8.68 NC overcast clouds
# Processing Record 34 of Set 1 | portland
# 45.5234 -122.6762 73.99 77 100 6.91 US overcast clouds
# Processing Record 35 of Set 1 | san ramon
# 37.7799 -121.978 86.31 48 0 5.75 US clear sky
# Processing Record 36 of Set 1 | ushuaia
# -54.8 -68.3 49.66 46 40 11.5 AR scattered clouds
# Processing Record 37 of Set 1 | esperance
# -33.8667 121.9 51.08 77 64 19.04 AU light rain
# Processing Record 38 of Set 1 | coulihaut
# City not found. Skipping...
# Processing Record 39 of Set 1 | hobart
# -42.8794 147.3294 50.25 80 75 8.05 AU broken clouds
# Processing Record 40 of Set 1 | albany
# 42.6001 -73.9662 65.88 83 98 3.78 US overcast clouds
# Processing Record 41 of Set 1 | sidi bu zayd
# City not found. Skipping...
# Processing Record 42 of Set 1 | lagoa
# 39.05 -27.9833 69.01 84 100 20.71 PT light rain
# Processing Record 43 of Set 1 | airai
# -8.9266 125.4092 58.96 79 89 2.28 TL overcast clouds
# Processing Record 44 of Set 1 | lucatan
# City not found. Skipping...
# Processing Record 45 of Set 1 | busselton
# -33.65 115.3333 48.6 63 12 8.5 AU few clouds
# Processing Record 46 of Set 1 | jamestown
# 42.097 -79.2353 68.05 44 0 9.22 US clear sky
# Processing Record 47 of Set 1 | kaitangata
# -46.2817 169.8464 36.95 83 100 14.29 NZ overcast clouds
# Processing Record 48 of Set 1 | khatanga
# 71.9667 102.5 6.4 99 84 3 RU broken clouds
# Processing Record 49 of Set 1 | diffa
# 13.3154 12.6113 86.68 46 13 7.16 NE few clouds
# Processing Record 50 of Set 1 | sao filipe
# 14.8961 -24.4956 79.45 80 50 6.76 CV scattered clouds
# Processing Record 1 of Set 2 | zonguldak
# 41.25 31.8333 52.74 80 99 1.28 TR overcast clouds
# Processing Record 2 of Set 2 | korla
# 41.7597 86.1469 55.26 34 0 7.05 CN clear sky
# Processing Record 3 of Set 2 | sembe
# 1.6481 14.5806 70.3 96 93 2.48 CG overcast clouds
# Processing Record 4 of Set 2 | thompson
# 55.7435 -97.8558 33.96 69 75 12.66 CA broken clouds
# Processing Record 5 of Set 2 | vila velha
# -20.3297 -40.2925 75.15 83 40 8.05 BR scattered clouds
# Processing Record 6 of Set 2 | saint anthony
# 45.0205 -93.218 73.45 64 75 10.36 US broken clouds
# Processing Record 7 of Set 2 | cumaral
# 4.2708 -73.4867 82.36 70 99 4.14 CO moderate rain
# Processing Record 8 of Set 2 | iqaluit
# 63.7506 -68.5145 33.53 93 100 8.05 CA light snow
# Processing Record 9 of Set 2 | tuatapere
# -46.1333 167.6833 38.01 85 100 14.56 NZ light rain
# Processing Record 10 of Set 2 | constitucion
# -35.3333 -72.4167 57.38 70 2 13.31 CL clear sky
# Processing Record 11 of Set 2 | shizuishan
# 39.2333 106.7694 49.12 43 7 3.49 CN clear sky
# Processing Record 12 of Set 2 | saint-philippe
# -21.3585 55.7679 69.39 79 53 10 RE broken clouds
# Processing Record 13 of Set 2 | fairbanks
# 64.8378 -147.7164 44.22 82 75 0 US broken clouds
# Processing Record 14 of Set 2 | nikolskoye
# 59.7035 30.7861 46.8 96 90 5.61 RU overcast clouds
# Processing Record 15 of Set 2 | kapaa
# 22.0752 -159.319 82.72 76 40 13.8 US scattered clouds
# Processing Record 16 of Set 2 | roebourne
# -20.7833 117.1333 72.21 33 11 12.91 AU few clouds
# Processing Record 17 of Set 2 | san luis
# -33.295 -66.3356 51.49 79 100 14.27 AR overcast clouds
# Processing Record 18 of Set 2 | bredasdorp
# -34.5322 20.0403 51.37 90 0 5.28 ZA clear sky
# Processing Record 19 of Set 2 | cap malheureux
# -19.9842 57.6142 70.47 71 62 5.01 MU broken clouds
# Processing Record 20 of Set 2 | vestmannaeyjar
# 63.4427 -20.2734 45.86 70 82 18.84 IS broken clouds
# Processing Record 21 of Set 2 | ketchikan
# 55.3422 -131.6461 57.67 94 100 13.8 US moderate rain
# Processing Record 22 of Set 2 | solnechnyy
# 50.7214 136.6319 31.06 51 5 8.9 RU clear sky
# Processing Record 23 of Set 2 | great falls
# 47.5002 -111.3008 74.59 41 0 6.91 US clear sky
# Processing Record 24 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 2 | goure
# 13.9835 10.2704 91.8 27 97 7.67 NE overcast clouds
# Processing Record 26 of Set 2 | vaini
# -21.2 -175.2 76.48 87 100 13.56 TO light rain
# Processing Record 27 of Set 2 | beloha
# -25.1667 45.05 68.38 88 0 4.7 MG clear sky
# Processing Record 28 of Set 2 | los mochis
# 25.7667 -108.9667 89.47 40 0 13.8 MX clear sky
# Processing Record 29 of Set 2 | new norfolk
# -42.7826 147.0587 49.91 68 100 3 AU overcast clouds
# Processing Record 30 of Set 2 | tiksi
# 71.6872 128.8694 23.16 78 96 19.26 RU overcast clouds
# Processing Record 31 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 2 | tsuruoka
# 38.7217 139.8217 54.93 63 99 3.47 JP overcast clouds
# Processing Record 33 of Set 2 | noshiro
# 40.2039 140.0242 52.05 59 95 9.51 JP overcast clouds
# Processing Record 34 of Set 2 | panzhihua
# 26.5851 101.7128 71.31 81 100 3.02 CN overcast clouds
# Processing Record 35 of Set 2 | adrar
# 20.5022 -10.0711 95.9 12 7 10.92 MR clear sky
# Processing Record 36 of Set 2 | galle
# 6.0367 80.217 77.27 89 100 12.59 LK overcast clouds
# Processing Record 37 of Set 2 | wajir
# 1.7471 40.0573 82.76 52 89 19.26 KE overcast clouds
# Processing Record 38 of Set 2 | auki
# -8.7676 160.7034 76.93 77 100 4.27 SB overcast clouds
# Processing Record 39 of Set 2 | smolenka
# 52.1352 113.4974 28.47 59 40 4.47 RU scattered clouds
# Processing Record 40 of Set 2 | muros
# 42.7762 -9.0603 69.15 82 97 12.8 ES overcast clouds
# Processing Record 41 of Set 2 | ribeira grande
# 38.5167 -28.7 70.2 88 75 4.61 PT broken clouds
# Processing Record 42 of Set 2 | berea
# 41.3662 -81.8543 76.21 41 20 9.22 US few clouds
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | santona
# 43.4439 -3.4576 66.6 91 0 5.12 ES clear sky
# Processing Record 45 of Set 2 | muisne
# 0.6 -80.0333 78.06 74 65 11.61 EC broken clouds
# Processing Record 46 of Set 2 | butaritari
# 3.0707 172.7902 81.79 71 9 20.27 KI clear sky
# Processing Record 47 of Set 2 | grand gaube
# -20.0064 57.6608 72 71 69 5.01 MU broken clouds
# Processing Record 48 of Set 2 | leningradskiy
# 69.3833 178.4167 26.73 87 100 12.12 RU overcast clouds
# Processing Record 49 of Set 2 | upernavik
# 72.7868 -56.1549 19.15 79 56 5.12 GL broken clouds
# Processing Record 50 of Set 2 | faanui
# -16.4833 -151.75 77.59 75 40 26.31 PF light rain
# Processing Record 1 of Set 3 | paamiut
# 61.994 -49.6678 36.68 93 100 9.64 GL overcast clouds
# Processing Record 2 of Set 3 | neuquen
# -38.9516 -68.0591 71.49 17 0 12.66 AR clear sky
# Processing Record 3 of Set 3 | kavieng
# -2.5744 150.7967 81.93 77 100 13.22 PG light rain
# Processing Record 4 of Set 3 | fallon
# 39.4735 -118.7774 79.45 15 0 4.61 US clear sky
# Processing Record 5 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 3 | dikson
# 73.5069 80.5464 30.49 76 92 6.55 RU overcast clouds
# Processing Record 7 of Set 3 | college
# 64.8569 -147.8028 44.2 83 75 0 US broken clouds
# Processing Record 8 of Set 3 | norman wells
# 65.282 -126.8329 46.44 71 40 13.8 CA scattered clouds
# Processing Record 9 of Set 3 | san patricio
# 28.017 -97.5169 89.69 33 48 8.77 US scattered clouds
# Processing Record 10 of Set 3 | porto santo
# 33.072 -16.3415 71.98 64 40 13.8 PT scattered clouds
# Processing Record 11 of Set 3 | viedma
# -40.8135 -62.9967 73.51 24 19 15.3 AR few clouds
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | imbituba
# -28.24 -48.6703 65.68 76 63 9.26 BR broken clouds
# Processing Record 14 of Set 3 | ribnitz-damgarten
# 54.25 12.4667 60.13 100 0 15.03 DE clear sky
# Processing Record 15 of Set 3 | komsomolskiy
# 40.4272 71.7189 54.32 40 91 6.91 UZ overcast clouds
# Processing Record 16 of Set 3 | mecca
# 21.4267 39.8261 85.82 37 0 4.38 SA clear sky
# Processing Record 17 of Set 3 | merauke
# -8.4667 140.3333 77.92 90 100 10.98 ID overcast clouds
# Processing Record 18 of Set 3 | helena
# 46.5927 -112.0361 71.26 55 0 1.99 US clear sky
# Processing Record 19 of Set 3 | carballo
# 43.213 -8.691 63.07 94 100 9.73 ES overcast clouds
# Processing Record 20 of Set 3 | harper
# 4.375 -7.7169 76.57 90 97 7.31 LR overcast clouds
# Processing Record 21 of Set 3 | sokolo
# 14.7328 -6.1219 90.5 38 3 5.44 ML clear sky
# Processing Record 22 of Set 3 | plouzane
# 48.3833 -4.6167 55.72 85 20 10.36 FR few clouds
# Processing Record 23 of Set 3 | hermanus
# -34.4187 19.2345 54.81 81 0 12.68 ZA clear sky
# Processing Record 24 of Set 3 | ambalavao
# -21.8333 46.9333 61.5 59 0 4.54 MG clear sky
# Processing Record 25 of Set 3 | marawi
# 7.9986 124.2928 68.47 91 100 0.47 PH overcast clouds
# Processing Record 26 of Set 3 | fort-shevchenko
# 44.5086 50.263 66.69 54 52 9.89 KZ broken clouds
# Processing Record 27 of Set 3 | torbay
# 47.6666 -52.7314 62.76 54 20 11.5 CA few clouds
# Processing Record 28 of Set 3 | lavrentiya
# 65.5833 -171 38.43 90 100 23.24 RU overcast clouds
# Processing Record 29 of Set 3 | gualaquiza
# -3.4 -78.55 83.71 45 76 3.56 EC broken clouds
# Processing Record 30 of Set 3 | souillac
# -20.5167 57.5167 71.98 73 20 8.05 MU few clouds
# Processing Record 31 of Set 3 | severo-kurilsk
# 50.6789 156.125 42.53 63 65 17.34 RU broken clouds
# Processing Record 32 of Set 3 | vardo
# 70.3705 31.1107 44.58 70 75 18.41 NO broken clouds
# Processing Record 33 of Set 3 | te anau
# -45.4167 167.7167 32.7 84 87 0.65 NZ overcast clouds
# Processing Record 34 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 3 | tacuarembo
# -31.7333 -55.9833 70.65 57 56 10.89 UY broken clouds
# Processing Record 36 of Set 3 | lasa
# 46.6166 10.7002 56.28 84 25 2.55 IT scattered clouds
# Processing Record 37 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 3 | tilichiki
# 60.4667 166.1 32.85 80 9 18.03 RU clear sky
# Processing Record 39 of Set 3 | saskylakh
# 71.9167 114.0833 4.24 98 81 4.56 RU broken clouds
# Processing Record 40 of Set 3 | ust-kulom
# 61.6864 53.6902 43.14 90 100 6.02 RU overcast clouds
# Processing Record 41 of Set 3 | korsakov
# 46.6328 142.7813 33.64 66 98 16.58 RU overcast clouds
# Processing Record 42 of Set 3 | nishihara
# 26.1842 127.7558 79.88 78 100 13.8 JP light rain
# Processing Record 43 of Set 3 | osoyoos
# 49.0331 -119.4524 72.36 40 73 1.14 CA broken clouds
# Processing Record 44 of Set 3 | cape town
# -33.9258 18.4232 59.88 68 0 5.01 ZA clear sky
# Processing Record 45 of Set 3 | east london
# -33.0153 27.9116 65.91 82 100 9.78 ZA overcast clouds
# Processing Record 46 of Set 3 | kapit
# 2.0167 112.9333 73.31 99 100 0.16 MY overcast clouds
# Processing Record 47 of Set 3 | luderitz
# -26.6481 15.1594 56.48 77 19 18.19 NA few clouds
# Processing Record 48 of Set 3 | goderich
# 43.7501 -81.7165 66.52 55 29 2.3 CA scattered clouds
# Processing Record 49 of Set 3 | mahebourg
# -20.4081 57.7 71.89 73 20 8.05 MU few clouds
# Processing Record 50 of Set 3 | sabaudia
# 41.3003 13.0282 68.47 92 9 6.33 IT clear sky
# Processing Record 1 of Set 4 | berlevag
# 70.8578 29.0864 42.75 75 0 20.71 NO clear sky
# Processing Record 2 of Set 4 | bilma
# 18.6853 12.9164 92.05 16 9 8.14 NE clear sky
# Processing Record 3 of Set 4 | muroto
# 33.2833 134.15 68.92 70 100 18.05 JP overcast clouds
# Processing Record 4 of Set 4 | nantucket
# 41.2835 -70.0995 62.71 98 100 14.97 US fog
# Processing Record 5 of Set 4 | chuy
# -33.6971 -53.4616 63.72 67 90 13.53 UY overcast clouds
# Processing Record 6 of Set 4 | milkovo
# 54.7167 158.6167 34.66 70 14 12.21 RU few clouds
# Processing Record 7 of Set 4 | chokurdakh
# 70.6333 147.9167 16.18 97 96 5.61 RU overcast clouds
# Processing Record 8 of Set 4 | timiryazevskoye
# 56.49 84.8769 34.09 93 100 4.16 RU overcast clouds
# Processing Record 9 of Set 4 | inirida
# 3.8653 -67.9239 86.27 67 96 1.9 CO light rain
# Processing Record 10 of Set 4 | cidreira
# -30.1811 -50.2056 64.4 76 54 16.75 BR broken clouds
# Processing Record 11 of Set 4 | havoysund
# 70.9963 24.6622 44.83 89 100 20.58 NO overcast clouds
# Processing Record 12 of Set 4 | sunrise manor
# 36.2111 -115.0731 92.88 15 0 7 US clear sky
# Processing Record 13 of Set 4 | tulln
# 48.3283 16.0586 58.95 86 100 1.14 AT overcast clouds
# Processing Record 14 of Set 4 | castro
# -24.7911 -50.0119 72.81 70 100 2.24 BR overcast clouds
# Processing Record 15 of Set 4 | mayo
# 38.8876 -76.5119 64.81 90 100 6.91 US mist
# Processing Record 16 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 17 of Set 4 | saint-augustin
# 51.226 -58.6502 58.14 66 25 12.01 CA scattered clouds
# Processing Record 18 of Set 4 | atambua
# -9.1061 124.8925 73.78 85 84 3.74 ID broken clouds
# Processing Record 19 of Set 4 | asau
# 46.4333 26.4 51.28 79 96 6.08 RO overcast clouds
# Processing Record 20 of Set 4 | bethel
# 41.3712 -73.414 62.19 86 100 7.45 US overcast clouds
# Processing Record 21 of Set 4 | semnan
# 35.5729 53.3971 73.47 31 0 6.96 IR clear sky
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | hami
# 42.8 93.45 52.74 46 0 4.97 CN clear sky
# Processing Record 24 of Set 4 | victoria
# 22.2855 114.1577 83.32 79 41 10 HK scattered clouds
# Processing Record 25 of Set 4 | bukama
# -9.2 25.85 79.7 46 97 4.43 CD overcast clouds
# Processing Record 26 of Set 4 | narsaq
# 60.9167 -46.05 39.42 90 100 11.92 GL overcast clouds
# Processing Record 27 of Set 4 | mokolo
# 10.7398 13.8019 72.39 72 17 1.9 CM few clouds
# Processing Record 28 of Set 4 | russell
# 32.3502 -85.1999 83.48 29 0 11.5 US clear sky
# Processing Record 29 of Set 4 | iraquara
# -12.2486 -41.6194 87.51 26 4 9.51 BR clear sky
# Processing Record 30 of Set 4 | mount isa
# -20.7333 139.5 67.77 100 65 4.61 AU broken clouds
# Processing Record 31 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 4 | la ronge
# 55.1001 -105.2842 43.02 45 40 9.22 CA scattered clouds
# Processing Record 33 of Set 4 | bubaque
# 11.2833 -15.8333 82.33 77 27 8.55 GW scattered clouds
# Processing Record 34 of Set 4 | alice springs
# -23.7 133.8833 58.55 77 0 4.61 AU clear sky
# Processing Record 35 of Set 4 | eirunepe
# -6.6603 -69.8736 91.89 46 87 1.57 BR overcast clouds
# Processing Record 36 of Set 4 | strezhevoy
# 60.7333 77.5889 34.43 81 89 4.47 RU overcast clouds
# Processing Record 37 of Set 4 | tiarei
# -17.5333 -149.3333 82.42 73 7 25.84 PF clear sky
# Processing Record 38 of Set 4 | kuusamo
# 65.9667 29.1833 44.64 93 75 12.66 FI broken clouds
# Processing Record 39 of Set 4 | la libertad
# -2.2333 -80.9 73.06 78 75 12.66 EC broken clouds
# Processing Record 40 of Set 4 | bonavista
# 48.6499 -53.1147 57.85 69 8 11.72 CA clear sky
# Processing Record 41 of Set 4 | beringovskiy
# 63.05 179.3167 44.37 93 100 26.02 RU moderate rain
# Processing Record 42 of Set 4 | wahpeton
# 46.2652 -96.6059 75.22 41 0 6.91 US clear sky
# Processing Record 43 of Set 4 | yeppoon
# -23.1333 150.7333 64.18 71 56 12.84 AU broken clouds
# Processing Record 44 of Set 4 | nome
# 64.5011 -165.4064 35.67 87 75 8.05 US broken clouds
# Processing Record 45 of Set 4 | kirkwood
# 38.5834 -90.4068 79.48 35 75 5.75 US broken clouds
# Processing Record 46 of Set 4 | dali
# 25.7 100.1833 61.29 93 92 4.12 CN overcast clouds
# Processing Record 47 of Set 4 | bangaon
# 23.0667 88.8167 76.75 94 23 5.39 IN few clouds
# Processing Record 48 of Set 4 | hilo
# 19.7297 -155.09 87.28 76 0 8.05 US clear sky
# Processing Record 49 of Set 4 | krasnoselkup
# 65.7 82.4667 32.67 93 100 8.48 RU overcast clouds
# Processing Record 50 of Set 4 | kodiak
# 57.79 -152.4072 53.11 87 100 21.85 US light rain
# Processing Record 1 of Set 5 | pendleton
# 45.6721 -118.7886 88.2 36 0 8.05 US clear sky
# Processing Record 2 of Set 5 | boguchany
# 58.3814 97.4531 32.11 96 100 5.3 RU overcast clouds
# Processing Record 3 of Set 5 | eureka
# 40.8021 -124.1637 69.21 72 18 3 US few clouds
# Processing Record 4 of Set 5 | bosaso
# 11.2842 49.1816 85.05 61 70 3.06 SO broken clouds
# Processing Record 5 of Set 5 | olafsvik
# 64.8945 -23.7142 44.33 68 100 9.28 IS overcast clouds
# Processing Record 6 of Set 5 | darhan
# 49.4867 105.9228 29.98 49 5 4 MN clear sky
# Processing Record 7 of Set 5 | oranjemund
# -28.55 16.4333 55.49 90 23 9.64 NA few clouds
# Processing Record 8 of Set 5 | puerto baquerizo moreno
# -0.9 -89.6 68.99 83 75 14.97 EC broken clouds
# Processing Record 9 of Set 5 | the valley
# 18.217 -63.0578 86.14 74 20 18.41 AI few clouds
# Processing Record 10 of Set 5 | mitsamiouli
# -11.3847 43.2844 75.09 78 2 3.67 KM clear sky
# Processing Record 11 of Set 5 | zarumilla
# -3.5031 -80.2731 82.24 78 20 5.75 PE few clouds
# Processing Record 12 of Set 5 | puerto ayora
# -0.7393 -90.3518 76.96 87 72 7 EC broken clouds
# Processing Record 13 of Set 5 | carnarvon
# -24.8667 113.6333 62.31 60 32 23.31 AU scattered clouds
# Processing Record 14 of Set 5 | pitlochry
# 56.7051 -3.7343 46.92 88 65 9.55 GB light rain
# Processing Record 15 of Set 5 | milledgeville
# 33.0801 -83.2321 84.09 32 0 4.18 US clear sky
# Processing Record 16 of Set 5 | shubarshi
# 48.5872 57.1869 50.16 24 99 9.82 KZ overcast clouds
# Processing Record 17 of Set 5 | ilulissat
# 69.2167 -51.1 26.62 63 20 1.14 GL few clouds
# Processing Record 18 of Set 5 | belaya gora
# 68.5333 146.4167 17.69 92 98 10.89 RU overcast clouds
# Processing Record 19 of Set 5 | jizan
# 17.3333 42.6667 90.54 65 67 2.3 SA broken clouds
# Processing Record 20 of Set 5 | menomonie
# 44.8755 -91.9193 73.27 73 0 3.44 US clear sky
# Processing Record 21 of Set 5 | naliya
# 23.2667 68.8333 80.06 72 31 10.27 IN scattered clouds
# Processing Record 22 of Set 5 | tommot
# 58.9564 126.2925 28.29 95 100 10.27 RU light snow
# Processing Record 23 of Set 5 | wanning
# 18.8003 110.3967 79.16 86 55 6.69 CN broken clouds
# Processing Record 24 of Set 5 | sibolga
# 1.7427 98.7792 74.84 87 100 2.37 ID light rain
# Processing Record 25 of Set 5 | vercelli
# 45.3231 8.4153 66.69 69 73 2.91 IT broken clouds
# Processing Record 26 of Set 5 | gaoua
# 10.2992 -3.2508 77.36 81 57 4.99 BF light rain
# Processing Record 27 of Set 5 | jaca
# 42.569 -0.5499 61.99 75 21 2.89 ES few clouds
# Processing Record 28 of Set 5 | pak phanang
# 8.3511 100.202 79.68 81 100 4.21 TH light rain
# Processing Record 29 of Set 5 | puerto escondido
# 15.85 -97.0667 86.83 58 20 6.91 MX few clouds
# Processing Record 30 of Set 5 | bandarbeyla
# 9.4942 50.8122 77.41 83 68 20.45 SO broken clouds
# Processing Record 31 of Set 5 | pokrovsk
# 48.282 37.1758 46.09 75 59 5.88 UA broken clouds
# Processing Record 32 of Set 5 | mehamn
# 71.0357 27.8492 42.71 82 100 14.74 NO overcast clouds
# Processing Record 33 of Set 5 | touros
# -5.1989 -35.4608 78.03 84 0 13.62 BR clear sky
# Processing Record 34 of Set 5 | izhma
# 65.0083 53.9113 44.15 89 100 6.38 RU overcast clouds
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | peniche
# 39.3558 -9.3811 65.08 92 0 14.12 PT clear sky
# Processing Record 37 of Set 5 | gorin
# 51.1983 136.6669 31.14 60 5 8.95 RU clear sky
# Processing Record 38 of Set 5 | nouadhibou
# 20.931 -17.0347 91.38 33 23 10.36 MR sand
# Processing Record 39 of Set 5 | erzin
# 36.9559 36.2 69.76 81 32 1.77 TR scattered clouds
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | rincon
# 32.296 -81.2354 80.56 37 20 10.36 US few clouds
# Processing Record 42 of Set 5 | pevek
# 69.7008 170.3133 29.34 84 100 8.7 RU light snow
# Processing Record 43 of Set 5 | salinopolis
# -0.6136 -47.3561 80.83 78 5 14.67 BR clear sky
# Processing Record 44 of Set 5 | deer lake
# 49.1667 -57.4316 60.66 44 20 9.22 CA few clouds
# Processing Record 45 of Set 5 | laguna
# 38.421 -121.4238 91.63 42 0 5.75 US clear sky
# Processing Record 46 of Set 5 | kenai
# 60.5544 -151.2583 53.02 78 100 21.85 US light rain
# Processing Record 47 of Set 5 | puerto colombia
# 10.9878 -74.9547 84.29 69 48 4.9 CO scattered clouds
# Processing Record 48 of Set 5 | lata
# 40.1629 -8.3327 64.92 86 1 1.79 PT clear sky
# Processing Record 49 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 50 of Set 5 | magistralnyy
# 56.1725 107.4458 25.05 81 67 3.6 RU broken clouds
# Processing Record 1 of Set 6 | obera
# -27.4871 -55.1199 76.93 67 43 5.12 AR light rain
# Processing Record 2 of Set 6 | lakatoro
# -16.0999 167.4164 80.1 76 53 13.94 VU broken clouds
# Processing Record 3 of Set 6 | byron bay
# -28.65 153.6167 59.94 84 100 2.3 AU overcast clouds
# Processing Record 4 of Set 6 | don sak
# 9.3168 99.6918 81.14 83 100 7.11 TH light rain
# Processing Record 5 of Set 6 | shetpe
# 44.1667 52.1167 63.86 12 42 16.24 KZ scattered clouds
# Processing Record 6 of Set 6 | mar del plata
# -38.0023 -57.5575 60.82 87 100 11.5 AR overcast clouds
# Processing Record 7 of Set 6 | avarua
# -21.2078 -159.775 77.05 69 40 18.41 CK scattered clouds
# Processing Record 8 of Set 6 | cape coast
# 5.1053 -1.2466 76.5 91 41 9.93 GH scattered clouds
# Processing Record 9 of Set 6 | manado
# 1.487 124.8455 77.77 94 40 2.3 ID scattered clouds
# Processing Record 10 of Set 6 | menongue
# -14.6585 17.691 69.64 21 67 4.99 AO broken clouds
# Processing Record 11 of Set 6 | coquimbo
# -29.9533 -71.3436 64.13 59 20 12.66 CL few clouds
# Processing Record 12 of Set 6 | flinders
# -34.5833 150.8552 58.37 93 100 3 AU light rain
# Processing Record 13 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 14 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 6 | los llanos de aridane
# 28.6585 -17.9182 72.12 88 0 13.8 ES clear sky
# Processing Record 16 of Set 6 | ukiah
# 39.1502 -123.2078 91.44 37 0 5.75 US clear sky
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | marsa matruh
# 31.3525 27.2453 73.6 56 0 11.5 EG clear sky
# Processing Record 19 of Set 6 | mirnyy
# 62.5353 113.9611 32.23 74 97 8.99 RU overcast clouds
# Processing Record 20 of Set 6 | mosquera
# 4.7059 -74.2302 55.49 94 75 6.91 CO broken clouds
# Processing Record 21 of Set 6 | codrington
# -38.2667 141.9667 55.6 93 98 10.98 AU overcast clouds
# Processing Record 22 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | batagay-alyta
# 67.8006 130.4114 17.47 95 100 3.91 RU light snow
# Processing Record 25 of Set 6 | okhotsk
# 59.3833 143.3 29.05 56 100 9.62 RU overcast clouds
# Processing Record 26 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 6 | chiredzi
# -21.05 31.6667 77.04 51 0 8.55 ZW clear sky
# Processing Record 28 of Set 6 | arequipa
# -16.3989 -71.535 66.27 22 0 11.5 PE clear sky
# Processing Record 29 of Set 6 | raga
# 8.4596 25.678 69.49 93 46 0.98 SS scattered clouds
# Processing Record 30 of Set 6 | saint-joseph
# -21.3667 55.6167 68.38 79 30 10.6 RE scattered clouds
# Processing Record 31 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 6 | narva-joesuu
# 59.4589 28.0408 52.79 95 100 10.27 EE overcast clouds
# Processing Record 33 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 6 | port hawkesbury
# 45.6169 -61.3485 60.58 86 100 9.22 CA overcast clouds
# Processing Record 35 of Set 6 | hovd
# 48.0056 91.6419 38.1 31 62 5.59 MN broken clouds
# Processing Record 36 of Set 6 | pizarro
# 4.9533 -77.366 81.03 76 78 7 CO broken clouds
# Processing Record 37 of Set 6 | puerto carreno
# 6.189 -67.4859 93.18 52 40 4.61 CO scattered clouds
# Processing Record 38 of Set 6 | chippewa falls
# 44.9369 -91.3929 72.37 61 0 3.44 US clear sky
# Processing Record 39 of Set 6 | bambous virieux
# -20.3428 57.7575 71.85 73 20 8.05 MU few clouds
# Processing Record 40 of Set 6 | ust-nera
# 64.5667 143.2 8.01 96 100 2.57 RU overcast clouds
# Processing Record 41 of Set 6 | alyangula
# -13.8483 136.4192 78.84 78 39 8.01 AU scattered clouds
# Processing Record 42 of Set 6 | havre-saint-pierre
# 50.2334 -63.5986 55.76 76 100 6.91 CA overcast clouds
# Processing Record 43 of Set 6 | bay roberts
# 47.5999 -53.2648 63.52 64 3 7.61 CA clear sky
# Processing Record 44 of Set 6 | santa fe
# -31.6333 -60.7 79.02 31 100 8.01 AR light rain
# Processing Record 45 of Set 6 | moerai
# -22.4333 -151.3333 72.28 66 96 19.39 PF overcast clouds
# Processing Record 46 of Set 6 | bathsheba
# 13.2167 -59.5167 79.41 83 75 18.41 BB broken clouds
# Processing Record 47 of Set 6 | agira
# 37.6562 14.5216 63.41 76 51 2.06 IT broken clouds
# Processing Record 48 of Set 6 | bulgan
# 48.8125 103.5347 27.43 51 66 3.85 MN broken clouds
# Processing Record 49 of Set 6 | barrow
# 71.2906 -156.7887 37.42 65 20 23.02 US few clouds
# Processing Record 50 of Set 6 | tiznit
# 29.5833 -9.5 70.86 56 14 1.21 MA few clouds
# Processing Record 1 of Set 7 | maningrida
# -12.0667 134.2667 77.2 79 62 7.07 AU broken clouds
# Processing Record 2 of Set 7 | hambantota
# 6.1241 81.1185 78.37 81 100 16.55 LK overcast clouds
# Processing Record 3 of Set 7 | la paz
# -16.5 -68.15 66.18 16 40 14.97 BO scattered clouds
# Processing Record 4 of Set 7 | lovington
# 32.944 -103.3485 65.25 47 85 8.03 US overcast clouds
# Processing Record 5 of Set 7 | saldanha
# -33.0117 17.9442 51.85 77 1 8.14 ZA clear sky
# Processing Record 6 of Set 7 | san quintin
# 30.4833 -115.95 72.73 72 14 9.73 MX few clouds
# Processing Record 7 of Set 7 | presidente olegario
# -18.4178 -46.4181 73.44 64 50 3.8 BR scattered clouds
# Processing Record 8 of Set 7 | comodoro rivadavia
# -45.8667 -67.5 62.46 29 0 14.97 AR clear sky
# Processing Record 9 of Set 7 | cabo san lucas
# 22.8909 -109.9124 91.62 58 0 12.66 MX clear sky
# Processing Record 10 of Set 7 | cherskiy
# 68.75 161.3 22.57 94 100 10.69 RU light snow
# Processing Record 11 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 7 | hasaki
# 35.7333 140.8333 59.4 77 100 23.42 JP light rain
# Processing Record 13 of Set 7 | royan
# 45.6285 -1.0281 64.78 94 16 8.12 FR few clouds
# Processing Record 14 of Set 7 | north branch
# 45.5113 -92.9802 72.01 72 54 1.99 US broken clouds
# Processing Record 15 of Set 7 | huarmey
# -10.0681 -78.1522 65.77 71 3 12.33 PE clear sky
# Processing Record 16 of Set 7 | salalah
# 17.0151 54.0924 78.89 83 20 3.44 OM few clouds
# Processing Record 17 of Set 7 | port elizabeth
# -33.918 25.5701 61.09 85 20 8.05 ZA few clouds
# Processing Record 18 of Set 7 | oussouye
# 12.485 -16.5469 77.18 84 13 7.23 SN few clouds
# Processing Record 19 of Set 7 | sioux lookout
# 50.1001 -91.917 51.87 93 100 5.75 CA light intensity shower rain
# Processing Record 20 of Set 7 | katsuura
# 35.1333 140.3 64.11 85 100 23.69 JP overcast clouds
# Processing Record 21 of Set 7 | matara
# 5.9485 80.5353 76.86 89 100 11.88 LK overcast clouds
# Processing Record 22 of Set 7 | georgiyevka
# 43.0369 74.7114 50.04 57 20 4.47 KZ few clouds
# Processing Record 23 of Set 7 | opuwo
# -18.0607 13.84 72.45 29 3 5.46 NA clear sky
# Processing Record 24 of Set 7 | acapulco
# 16.8634 -99.8901 87.62 66 40 6.91 MX scattered clouds
# Processing Record 25 of Set 7 | namibe
# -15.1961 12.1522 64.71 84 76 1.86 AO broken clouds
# Processing Record 26 of Set 7 | ulaangom
# 49.9811 92.0667 35.13 48 100 1.01 MN overcast clouds
# Processing Record 27 of Set 7 | birao
# 10.2849 22.7882 74.89 76 14 4.63 CF few clouds
# Processing Record 28 of Set 7 | seoul
# 37.5683 126.9778 58.39 85 40 5.75 KR scattered clouds
# Processing Record 29 of Set 7 | sambava
# -14.2667 50.1667 68.13 89 6 9.33 MG clear sky
# Processing Record 30 of Set 7 | ponta delgada
# 37.7333 -25.6667 71.51 88 75 5.75 PT broken clouds
# Processing Record 31 of Set 7 | ancud
# -41.8697 -73.8203 48.45 93 100 26.6 CL moderate rain
# Processing Record 32 of Set 7 | bagotville
# -28.9833 153.4167 59.85 99 100 2.15 AU overcast clouds
# Processing Record 33 of Set 7 | port-cartier
# 50.0334 -66.8654 53.82 88 99 1.63 CA overcast clouds
# Processing Record 34 of Set 7 | sinop
# 41.7711 34.8709 51.37 91 46 1.03 TR scattered clouds
# Processing Record 35 of Set 7 | fort nelson
# 58.8053 -122.7002 42.39 75 75 3.44 CA broken clouds
# Processing Record 36 of Set 7 | shellbrook
# 53.2168 -106.4011 47.43 33 70 9.89 CA broken clouds
# Processing Record 37 of Set 7 | karpathos
# 35.507 27.2132 69.76 60 0 29.93 GR clear sky
# Processing Record 38 of Set 7 | kruisfontein
# -34.0033 24.7314 54.88 83 84 4.07 ZA broken clouds
# Processing Record 39 of Set 7 | gilgit
# 35.9221 74.3087 65.86 38 24 4.7 PK few clouds
# Processing Record 40 of Set 7 | husavik
# 66.0449 -17.3389 37.56 98 100 30.18 IS overcast clouds
# Processing Record 41 of Set 7 | maamba
# -17.3667 27.15 76.08 26 0 3 ZM clear sky
# Processing Record 42 of Set 7 | buin
# -33.7333 -70.75 64.72 54 85 7.74 CL overcast clouds
# Processing Record 43 of Set 7 | port lincoln
# -34.7333 135.8667 54.09 90 2 7.65 AU clear sky
# Processing Record 44 of Set 7 | yumen
# 40.2833 97.2 40.68 59 6 4.25 CN clear sky
# Processing Record 45 of Set 7 | awbari
# 26.5921 12.7805 74.62 32 2 7.96 LY clear sky
# Processing Record 46 of Set 7 | mzimba
# -11.9 33.6 64.87 47 7 9.37 MW clear sky
# Processing Record 47 of Set 7 | serenje
# -13.2325 30.2352 70.63 26 22 11.52 ZM few clouds
# Processing Record 48 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 7 | koppang
# 61.5706 11.0555 49.51 83 100 5.73 NO light rain
# Processing Record 50 of Set 7 | alofi
# -19.0595 -169.9187 80.49 74 40 11.5 NU scattered clouds
# Processing Record 1 of Set 8 | mulege
# 26.8833 -111.9833 88.99 30 0 8.63 MX clear sky
# Processing Record 2 of Set 8 | kashary
# 49.04 41.0056 52.27 68 61 7.76 RU broken clouds
# Processing Record 3 of Set 8 | moron
# -34.6534 -58.6198 74.01 58 87 8.59 AR overcast clouds
# Processing Record 4 of Set 8 | illapel
# -31.6308 -71.1653 61.03 60 55 7.05 CL broken clouds
# Processing Record 5 of Set 8 | haines junction
# 60.7522 -137.5108 46.35 66 100 1.14 CA overcast clouds
# Processing Record 6 of Set 8 | sabang
# 5.8933 95.3214 78.8 82 100 16.67 ID light rain
# Processing Record 7 of Set 8 | denau
# City not found. Skipping...
# Processing Record 8 of Set 8 | dondo
# -19.6094 34.7431 74.71 95 0 5.21 MZ clear sky
# Processing Record 9 of Set 8 | nanhai
# 30.1282 111.7784 48.78 79 100 12.41 CN overcast clouds
# Processing Record 10 of Set 8 | tripoli
# 32.8752 13.1875 74.44 59 3 14.25 LY clear sky
# Processing Record 11 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 8 | ugoofaaru
# 5.6667 73 81.43 78 100 18.43 MV overcast clouds
# Processing Record 13 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 8 | quatre cocos
# -20.2078 57.7625 71.71 68 72 13.38 MU broken clouds
# Processing Record 15 of Set 8 | mareeba
# -17 145.4333 69.44 93 93 4.05 AU overcast clouds
# Processing Record 16 of Set 8 | atar
# 20.5169 -13.0499 96.55 14 44 12.62 MR scattered clouds
# Processing Record 17 of Set 8 | mount gambier
# -37.8333 140.7667 57.11 94 100 12.66 AU overcast clouds
# Processing Record 18 of Set 8 | mme
# City not found. Skipping...
# Processing Record 19 of Set 8 | kyra
# 49.5776 111.9753 22.19 76 27 3.18 RU scattered clouds
# Processing Record 20 of Set 8 | georgetown
# 5.4112 100.3354 77.9 97 40 5.01 MY light rain
# Processing Record 21 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 8 | sol-iletsk
# 51.1631 54.9918 57.65 20 100 15.17 RU overcast clouds
# Processing Record 23 of Set 8 | svetlyy
# 54.675 20.1347 51.96 75 84 13.58 RU broken clouds
# Processing Record 24 of Set 8 | poum
# -20.2333 164.0167 72.9 65 61 9.44 NC broken clouds
# Processing Record 25 of Set 8 | iskateley
# 67.6803 53.1512 43.05 97 100 6.38 RU overcast clouds
# Processing Record 26 of Set 8 | vostok
# 46.4856 135.8833 24.62 82 22 4.97 RU few clouds
# Processing Record 27 of Set 8 | teguise
# 29.0605 -13.564 70.02 78 20 17.27 ES few clouds
# Processing Record 28 of Set 8 | sao miguel do araguaia
# -13.275 -50.1628 95.83 22 63 4.99 BR broken clouds
# Processing Record 29 of Set 8 | bac lieu
# 9.285 105.7244 78.19 88 100 6.51 VN moderate rain
# Processing Record 30 of Set 8 | sabzevar
# 36.2126 57.6819 61.88 25 0 9.22 IR clear sky
# Processing Record 31 of Set 8 | sobolevo
# 54.4299 31.8996 44.89 97 100 8.52 RU overcast clouds
# Processing Record 32 of Set 8 | sao joao da barra
# -21.6403 -41.0511 75.29 88 56 10.67 BR broken clouds
# Processing Record 33 of Set 8 | istok
# 42.7808 20.4875 50.86 68 100 2.24 XK overcast clouds
# Processing Record 34 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 8 | honningsvag
# 70.9821 25.9704 44.35 76 100 18.41 NO overcast clouds
# Processing Record 36 of Set 8 | kalmunai
# 7.4167 81.8167 78.73 80 100 4.72 LK overcast clouds
# Processing Record 37 of Set 8 | sao gabriel
# -30.3364 -54.32 68.88 68 99 11.01 BR light rain
# Processing Record 38 of Set 8 | benguela
# -12.5763 13.4055 73.6 78 97 8.66 AO overcast clouds
# Processing Record 39 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 8 | carutapera
# -1.195 -46.02 80.67 74 12 10.87 BR few clouds
# Processing Record 41 of Set 8 | ahipara
# -35.1667 173.1667 53.11 67 99 19.19 NZ overcast clouds
# Processing Record 42 of Set 8 | pochutla
# 15.7432 -96.4661 88.83 64 46 5.26 MX scattered clouds
# Processing Record 43 of Set 8 | gornyye klyuchi
# 45.25 133.5 29.39 73 1 3.36 RU clear sky
# Processing Record 44 of Set 8 | tual
# -5.6667 132.75 82.78 76 100 8.16 ID overcast clouds
# Processing Record 45 of Set 8 | san cristobal
# 7.7669 -72.225 78.98 88 100 1.45 VE overcast clouds
# Processing Record 46 of Set 8 | vitim
# 59.4511 112.5578 28.11 76 99 6.85 RU overcast clouds
# Processing Record 47 of Set 8 | mogadishu
# 2.0371 45.3438 77.67 85 81 13.4 SO broken clouds
# Processing Record 48 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 8 | atocha
# -20.9333 -66.2333 53.69 5 3 31.63 BO clear sky
# Processing Record 50 of Set 8 | hervey bay
# -25.2986 152.8535 63.01 86 40 14 AU scattered clouds
# Processing Record 1 of Set 9 | lorengau
# -2.0226 147.2712 83.34 71 56 12.73 PG broken clouds
# Processing Record 2 of Set 9 | yuli
# 9.6989 10.2744 75 80 29 1.5 NG light rain
# Processing Record 3 of Set 9 | kracheh
# City not found. Skipping...
# Processing Record 4 of Set 9 | nabire
# -3.3667 135.4833 74.71 93 87 2.98 ID overcast clouds
# Processing Record 5 of Set 9 | vargem alta
# -20.6714 -41.0069 65.61 96 87 3.4 BR overcast clouds
# Processing Record 6 of Set 9 | margate
# 51.3813 1.3862 55.87 70 7 7 GB clear sky
# Processing Record 7 of Set 9 | nelson bay
# -32.7167 152.15 62.01 97 100 8.01 AU overcast clouds
# Processing Record 8 of Set 9 | yambio
# 4.5721 28.3955 68.4 96 69 2.89 SS light rain
# Processing Record 9 of Set 9 | kingston
# 17.997 -76.7936 88.75 77 20 13.8 JM few clouds
# Processing Record 10 of Set 9 | yellowknife
# 62.456 -114.3525 37.92 65 75 15.01 CA broken clouds
# Processing Record 11 of Set 9 | villa carlos paz
# -31.4241 -64.4978 54.9 48 100 10 AR overcast clouds
# Processing Record 12 of Set 9 | arrifes
# 37.7667 -25.7 69.24 88 75 5.75 PT broken clouds
# Processing Record 13 of Set 9 | mafinga
# -7.25 35.0667 72.09 40 6 6.51 TZ clear sky
# Processing Record 14 of Set 9 | san rafael
# -34.6177 -68.3301 65.46 30 47 11.39 AR scattered clouds
# Processing Record 15 of Set 9 | keokuk
# 40.3973 -91.3849 74.08 52 75 5.75 US broken clouds
# Processing Record 16 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 9 | riyadh
# 24.6877 46.7219 78.94 15 0 2.93 SA clear sky
# Processing Record 18 of Set 9 | terre haute
# 39.4667 -87.4139 79.21 24 0 0 US clear sky
# Processing Record 19 of Set 9 | yulara
# -25.2406 130.9889 64.6 31 0 4.5 AU clear sky
# Processing Record 20 of Set 9 | wawa
# 9.9022 4.4192 76.95 85 100 1.68 NG overcast clouds
# Processing Record 21 of Set 9 | hofn
# 64.2539 -15.2082 43.27 57 6 12.46 IS clear sky
# Processing Record 22 of Set 9 | cavalcante
# -13.7975 -47.4583 83.84 39 66 5.01 BR broken clouds
# Processing Record 23 of Set 9 | waipawa
# -41.4122 175.5153 37.08 86 97 19.35 NZ overcast clouds
# Processing Record 24 of Set 9 | suntar
# 62.1444 117.6319 30.81 82 100 11.56 RU overcast clouds
# Processing Record 25 of Set 9 | sabha
# 27.0377 14.4283 74.66 37 0 10.45 LY clear sky
# Processing Record 26 of Set 9 | tocache
# -8.1842 -76.5125 88.25 51 98 2.86 PE overcast clouds
# Processing Record 27 of Set 9 | little current
# 45.9793 -81.9248 64.42 58 96 8.95 CA overcast clouds
# Processing Record 28 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 9 | sur
# 22.5667 59.5289 81.32 60 1 8.14 OM clear sky
# Processing Record 30 of Set 9 | inhambane
# -23.865 35.3833 71.98 90 0 10.4 MZ clear sky
# Processing Record 31 of Set 9 | aklavik
# 68.2191 -135.0107 33.84 91 100 11.45 CA overcast clouds
# Processing Record 32 of Set 9 | port hardy
# 50.6996 -127.4199 62.78 77 40 3.44 CA scattered clouds
# Processing Record 33 of Set 9 | boden
# 65.8252 21.6886 48.2 98 100 5.97 SE overcast clouds
# Processing Record 34 of Set 9 | ixtapa
# 20.7 -105.2 87.22 66 40 8.05 MX scattered clouds
# Processing Record 35 of Set 9 | kamenka
# 51.3223 42.7678 48.11 82 89 9.73 RU overcast clouds
# Processing Record 36 of Set 9 | san rafael del sur
# 11.8485 -86.4384 88.77 71 65 3.2 NI broken clouds
# Processing Record 37 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 9 | sao jose da coroa grande
# -8.8978 -35.1478 77.07 85 9 8.57 BR clear sky
# Processing Record 39 of Set 9 | trinidad
# -14.8333 -64.9 91.38 52 40 11.5 BO scattered clouds
# Processing Record 40 of Set 9 | dakar
# 14.6937 -17.4441 84.33 84 40 13.8 SN scattered clouds
# Processing Record 41 of Set 9 | katghora
# 22.5 82.55 72.68 97 100 2.24 IN overcast clouds
# Processing Record 42 of Set 9 | aquiraz
# -3.9014 -38.3911 82.49 83 4 14.05 BR clear sky
# Processing Record 43 of Set 9 | muravlenko
# 63.7898 74.523 31.98 83 77 3.42 RU broken clouds
# Processing Record 44 of Set 9 | areia branca
# -4.9561 -37.1369 80.26 76 0 25.48 BR clear sky
# Processing Record 45 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 46 of Set 9 | meulaboh
# 4.1363 96.1285 74.01 93 100 2.89 ID moderate rain
# Processing Record 47 of Set 9 | copiapo
# -27.3667 -70.3333 60.49 39 0 8.75 CL clear sky
# Processing Record 48 of Set 9 | port hedland
# -20.3167 118.5667 64.45 94 0 2.3 AU clear sky
# Processing Record 49 of Set 9 | pisco
# -13.7 -76.2167 68.05 60 0 11.5 PE clear sky
# Processing Record 50 of Set 9 | coihaique
# -45.5752 -72.0662 49.95 62 100 6.91 CL overcast clouds
# Processing Record 1 of Set 10 | sumbe
# -11.2061 13.8437 73.78 85 60 9.86 AO broken clouds
# Processing Record 2 of Set 10 | cilegon
# -6.0174 106.0538 78.66 81 67 2.98 ID broken clouds
# Processing Record 3 of Set 10 | najran
# 17.4924 44.1277 81.25 24 82 3.8 SA broken clouds
# Processing Record 4 of Set 10 | panlaitan
# 12.1191 119.8486 81.79 79 95 2.64 PH overcast clouds
# Processing Record 5 of Set 10 | grootfontein
# -19.5667 18.1167 67.57 28 44 3.44 NA scattered clouds
# Processing Record 6 of Set 10 | kemijarvi
# 66.7131 27.4306 44.42 89 100 12.15 FI overcast clouds
# Processing Record 7 of Set 10 | makakilo city
# 21.3469 -158.0858 82.98 62 40 10.36 US scattered clouds
# Processing Record 8 of Set 10 | ewa beach
# 21.3156 -158.0072 84.4 63 40 10.36 US scattered clouds
# Processing Record 9 of Set 10 | khewra
# 32.6479 73.0106 77.07 45 0 5.12 PK clear sky
# Processing Record 10 of Set 10 | skibbereen
# 51.55 -9.2667 56.1 70 0 17.58 IE clear sky
# Processing Record 11 of Set 10 | katherine
# -14.4667 132.2667 82.72 69 40 1.14 AU scattered clouds
# Processing Record 12 of Set 10 | aurora
# 39.7294 -104.8319 69.69 47 40 4.61 US scattered clouds
# Processing Record 13 of Set 10 | wattegama
# 6.7989 81.4808 74.26 87 100 5.19 LK overcast clouds
# Processing Record 14 of Set 10 | caravelas
# -17.7125 -39.2481 75.85 80 86 10.29 BR overcast clouds
# Processing Record 15 of Set 10 | batemans bay
# -35.7167 150.1833 57.09 95 100 12.5 AU light rain
# Processing Record 16 of Set 10 | qiyang
# 26.5911 111.8474 56.43 75 100 5.48 CN overcast clouds
# Processing Record 17 of Set 10 | antalaha
# -14.9003 50.2788 67.59 87 1 6.85 MG clear sky
# Processing Record 18 of Set 10 | krasnyye tkachi
# 57.4926 39.7563 46.22 93 100 5.95 RU overcast clouds
# Processing Record 19 of Set 10 | sulangan
# 11.1373 123.7228 82.92 76 100 7.67 PH overcast clouds
# Processing Record 20 of Set 10 | petropavlovsk-kamchatskiy
# 53.0452 158.6483 34.39 93 75 2.24 RU broken clouds
# Processing Record 21 of Set 10 | ikwiriri
# -7.9562 38.9716 69.67 92 8 4.32 TZ clear sky
# Processing Record 22 of Set 10 | faya
# 18.3851 42.4509 71.71 31 40 6.38 SA scattered clouds
# Processing Record 23 of Set 10 | fomboni
# -12.28 43.7425 76.05 75 1 4.97 KM clear sky
# Processing Record 24 of Set 10 | roald
# 62.5833 6.1333 51.94 76 0 19.57 NO clear sky
# Processing Record 25 of Set 10 | kailua
# 21.4022 -157.7394 84.43 71 40 6.91 US scattered clouds
# Processing Record 26 of Set 10 | stephenville
# 32.2207 -98.2023 89.73 21 0 6.91 US clear sky
# Processing Record 27 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 28 of Set 10 | conde
# -7.2597 -34.9075 78.26 78 75 9.22 BR broken clouds
# Processing Record 29 of Set 10 | bowen
# -20.0167 148.2333 73.69 77 15 11.56 AU few clouds
# Processing Record 30 of Set 10 | kamaishi
# 39.2667 141.8833 50.13 67 68 5.66 JP broken clouds
# Processing Record 31 of Set 10 | ngunguru
# -35.6167 174.5 53.04 64 87 17.09 NZ overcast clouds
# Processing Record 32 of Set 10 | ryotsu
# 38.0833 138.4333 56.73 65 100 8.43 JP overcast clouds
# Processing Record 33 of Set 10 | araouane
# 18.9048 -3.5265 97.16 19 46 4.74 ML scattered clouds
# Processing Record 34 of Set 10 | provideniya
# 64.3833 -173.3 40.24 96 100 16.69 RU light rain
# Processing Record 35 of Set 10 | garowe
# 8.4054 48.4845 80.01 59 94 13.71 SO overcast clouds
# Processing Record 36 of Set 10 | palmer
# 42.1584 -72.3287 60.62 84 100 11.5 US light intensity drizzle
# Processing Record 37 of Set 10 | marzuq
# 14.4 46.4667 74.17 55 43 1.72 YE scattered clouds
# Processing Record 38 of Set 10 | minsk
# 53.9 27.5667 51.55 90 100 8.41 BY overcast clouds
# Processing Record 39 of Set 10 | rawson
# -43.3002 -65.1023 67.86 27 36 21.54 AR scattered clouds
# Processing Record 40 of Set 10 | bereda
# 43.2686 -7.5406 62.42 100 100 6.89 ES overcast clouds
# Processing Record 41 of Set 10 | geraldton
# -28.7667 114.6 54.01 82 100 4.61 AU overcast clouds
# Processing Record 42 of Set 10 | santa cruz verapaz
# 15.3667 -90.4333 74.16 60 75 4.61 GT broken clouds
# Processing Record 43 of Set 10 | diego de almagro
# -26.3667 -70.05 63.54 23 0 9.55 CL clear sky
# Processing Record 44 of Set 10 | askino
# 56.0901 56.5783 46.62 67 100 9.8 RU light rain
# Processing Record 45 of Set 10 | banda aceh
# 5.5577 95.3222 76.82 87 100 10.63 ID moderate rain
# Processing Record 46 of Set 10 | bonga
# 7.2833 36.2333 59.11 99 98 1.39 ET light rain
# Processing Record 47 of Set 10 | kargil
# 34.5667 76.1 43.65 54 0 5.91 IN clear sky
# Processing Record 48 of Set 10 | vila franca do campo
# 37.7167 -25.4333 71.2 89 97 10.4 PT light rain
# Processing Record 49 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 10 | saint-pierre
# -21.3393 55.4781 69.48 73 0 8.05 RE clear sky
# Processing Record 1 of Set 11 | ibra
# 22.6906 58.5334 77.27 55 2 3.02 OM clear sky
# Processing Record 2 of Set 11 | flin flon
# 54.7682 -101.865 39.04 52 40 13.8 CA scattered clouds
# Processing Record 3 of Set 11 | colchester
# 51.8892 0.9042 56.73 73 1 20.45 GB clear sky
# Processing Record 4 of Set 11 | henties bay
# -22.116 14.2845 54.46 93 8 7.83 NA clear sky
# Processing Record 5 of Set 11 | westfield
# 42.1251 -72.7495 64.38 91 100 11.5 US mist
# Processing Record 6 of Set 11 | estelle
# 29.8458 -90.1067 86 45 75 8.05 US broken clouds
# Processing Record 7 of Set 11 | plettenberg bay
# -34.0527 23.3716 55 86 99 3.42 ZA overcast clouds
# Processing Record 8 of Set 11 | dryden
# 49.7833 -92.7503 52.09 87 100 3.44 CA overcast clouds
# Processing Record 9 of Set 11 | qaqortoq
# 60.7167 -46.0333 37.44 85 100 16.15 GL overcast clouds
# Processing Record 10 of Set 11 | tevaitoa
# -16.7833 -151.5 77.86 74 34 26.49 PF scattered clouds
# Processing Record 11 of Set 11 | denpasar
# -8.65 115.2167 78.46 88 40 2.3 ID scattered clouds
# Processing Record 12 of Set 11 | arteaga
# 18.4667 -102.4167 74.32 77 37 4.14 MX scattered clouds
# Processing Record 13 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 11 | tura
# 25.5198 90.2201 70.95 97 93 3.09 IN overcast clouds
# Processing Record 15 of Set 11 | praia
# 14.9215 -23.5087 82.94 78 20 6.91 CV few clouds
# Processing Record 16 of Set 11 | morondava
# -20.2833 44.2833 75.51 83 0 5.93 MG clear sky
# Processing Record 17 of Set 11 | kanigoro
# -8.13 112.219 73.83 93 100 6.8 ID overcast clouds
# Processing Record 18 of Set 11 | evensk
# 61.95 159.2333 29.14 80 94 15.01 RU overcast clouds
# Processing Record 19 of Set 11 | dunedin
# -45.8742 170.5036 36.97 91 98 18.39 NZ overcast clouds
# Processing Record 20 of Set 11 | barentu
# 15.1139 37.5928 78.66 30 46 4.72 ER scattered clouds
# Processing Record 21 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 11 | hollola
# 61.05 25.4333 52.5 98 100 9.22 FI overcast clouds
# Processing Record 23 of Set 11 | havelock
# 34.8791 -76.9013 71.94 63 75 11.5 US broken clouds
# Processing Record 24 of Set 11 | ales
# 44.1333 4.0833 61.88 94 0 2.24 FR clear sky
# Processing Record 25 of Set 11 | tazovskiy
# 67.4667 78.7 34.43 76 100 3.76 RU overcast clouds
# Processing Record 26 of Set 11 | kupang
# -10.1667 123.5833 78.04 85 100 5.68 ID overcast clouds
# Processing Record 27 of Set 11 | ambon
# -3.6954 128.1814 75.34 94 20 4.61 ID few clouds
# Processing Record 28 of Set 11 | lakhnau
# 26.85 80.9167 75.18 94 100 3.44 IN light rain
# Processing Record 29 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 30 of Set 11 | brokopondo
# 4.75 -55.1667 87.91 58 29 1.99 SR scattered clouds
# Processing Record 31 of Set 11 | chauk
# 20.8833 94.8167 78.84 82 63 3.2 MM broken clouds
# Processing Record 32 of Set 11 | berzence
# 46.2091 17.1481 54.59 70 100 5.99 HU overcast clouds
# Processing Record 33 of Set 11 | kaeo
# -35.1 173.7833 54.32 88 67 13.24 NZ broken clouds
# Processing Record 34 of Set 11 | ust-kuyga
# 70.0167 135.6 21.43 96 100 6.08 RU snow
# Processing Record 35 of Set 11 | chimoio
# -19.1164 33.4833 71.46 94 0 2.82 MZ clear sky
# Processing Record 36 of Set 11 | bassila
# 9.0081 1.6654 72.48 94 100 4.27 BJ overcast clouds
# Processing Record 37 of Set 11 | zaykovo
# 57.5613 62.7568 46.87 65 100 4.99 RU overcast clouds
# ...
# Processing Record 47 of Set 12 | walvis bay
# -22.9575 14.5053 56.35 82 0 5.75 NA clear sky
# Processing Record 48 of Set 12 | broken hill
# -31.95 141.4333 65.26 51 0 5.46 AU clear sky
# Processing Record 49 of Set 12 | khairpur nathan shah
# 27.0936 67.7337 84.54 35 0 9.04 PK clear sky
# Processing Record 50 of Set 12 | emba
# 48.8264 58.1442 49.69 21 97 8.63 KZ overcast clouds
# Processing Record 1 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 13 | rioblanco
# 3.5308 -75.6806 71.55 75 75 2.35 CO broken clouds
# Processing Record 3 of Set 13 | mbini
# 1.574 9.6134 77.29 89 99 4.56 GQ light rain
# Processing Record 4 of Set 13 | kodinsk
# 58.6881 99.1844 33.17 98 100 4.94 RU light snow
# Processing Record 5 of Set 13 | villacarrillo
# 38.1156 -3.0848 66.6 53 16 4.38 ES few clouds
# Processing Record 6 of Set 13 | hamilton
# 39.1834 -84.5333 78.53 30 0 1.99 US clear sky
# Processing Record 7 of Set 13 | impfondo
# 1.6381 18.0667 74.88 81 72 0.45 CG broken clouds
# Processing Record 8 of Set 13 | loikaw
# 19.6742 97.2094 65.07 94 11 1.95 MM few clouds
# Processing Record 9 of Set 13 | yar-sale
# 66.8333 70.8333 32.76 91 39 9.44 RU scattered clouds
# Processing Record 10 of Set 13 | westport
# 41.1415 -73.3579 61.59 90 100 11.5 US moderate rain
# Processing Record 11 of Set 13 | guelengdeng
# City not found. Skipping...
# Processing Record 12 of Set 13 | anori
# -3.7728 -61.6442 91.02 41 96 2.24 BR overcast clouds
# Processing Record 13 of Set 13 | tombouctou
# 20 -3 94.73 19 93 5.06 ML overcast clouds
# Processing Record 14 of Set 13 | constantine
# 36.365 6.6147 65.61 77 40 4.61 DZ scattered clouds
# Processing Record 15 of Set 13 | yahotyn
# 50.2798 31.7625 48.52 86 100 6.69 UA overcast clouds
# Processing Record 16 of Set 13 | binga
# -17.6203 27.3414 76.62 35 0 1.03 ZW clear sky
# Processing Record 17 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 13 | spring valley
# 36.108 -115.245 91.29 18 20 8.05 US few clouds
# Processing Record 19 of Set 13 | lae
# -6.7221 146.9847 77.67 83 99 4.36 PG overcast clouds
# Processing Record 20 of Set 13 | imeni poliny osipenko
# 52.4201 136.4853 27.61 58 7 4.81 RU clear sky
# Processing Record 21 of Set 13 | innisfail
# -17.5333 146.0333 75.33 86 88 4.52 AU overcast clouds
# Processing Record 22 of Set 13 | kungurtug
# 50.5994 97.5228 30.36 44 100 1.52 RU overcast clouds
# Processing Record 23 of Set 13 | port said
# 31.2565 32.2841 78.78 73 40 5.75 EG scattered clouds
# Processing Record 24 of Set 13 | moosomin
# 50.1333 -101.6677 57.63 41 100 17.76 CA overcast clouds
# Processing Record 25 of Set 13 | port macquarie
# -31.4333 152.9167 57.88 90 100 5.79 AU overcast clouds
# Processing Record 26 of Set 13 | vorselaar
# 51.2029 4.7709 63.05 83 100 3 BE overcast clouds
# Processing Record 27 of Set 13 | presidente epitacio
# -21.7633 -52.1156 85.69 47 49 3.13 BR scattered clouds
# Processing Record 28 of Set 13 | kloulklubed
# 7.0419 134.2556 73.9 74 75 9.22 PW broken clouds
# Processing Record 29 of Set 13 | komatipoort
# -25.4332 31.9548 76.41 46 0 3.56 ZA clear sky
# Processing Record 30 of Set 13 | sirohi
# 24.8833 72.8667 79.34 48 84 3.36 IN broken clouds
# Processing Record 31 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 13 | chimbote
# -9.0853 -78.5783 64.71 72 8 13.2 PE clear sky
# Processing Record 33 of Set 13 | broome
# 42.2506 -75.833 68.68 54 40 3.44 US scattered clouds
# Processing Record 34 of Set 13 | turbat
# 26.0023 63.044 79.72 65 0 2.64 PK clear sky
# Processing Record 35 of Set 13 | chekhov
# 55.1431 37.4711 44.1 94 100 5.99 RU overcast clouds
# Processing Record 36 of Set 13 | kapuskasing
# 49.4169 -82.4331 62.69 82 100 10.36 CA moderate rain
# Processing Record 37 of Set 13 | port blair
# 11.6667 92.75 80.17 83 100 11.92 IN overcast clouds
# Processing Record 38 of Set 13 | sept-iles
# 50.2001 -66.3821 54.12 83 100 4.61 CA overcast clouds
# Processing Record 39 of Set 13 | tonantins
# -2.8731 -67.8022 90 55 70 2.71 BR broken clouds
# Processing Record 40 of Set 13 | traverse city
# 44.7631 -85.6206 73.51 38 75 9.22 US broken clouds
# Processing Record 41 of Set 13 | cap-aux-meules
# 47.3821 -61.8597 59.05 82 40 8.05 CA scattered clouds
# Processing Record 42 of Set 13 | allanmyo
# City not found. Skipping...
# Processing Record 43 of Set 13 | tamandare
# -8.7597 -35.1047 76.89 85 6 7.96 BR clear sky
# Processing Record 44 of Set 13 | synya
# 65.3718 58.0387 42.57 88 100 5.08 RU overcast clouds
# Processing Record 45 of Set 13 | novikovo
# 51.1537 37.8879 44.46 92 40 7.14 RU scattered clouds
# Processing Record 46 of Set 13 | talas
# 38.6908 35.5538 56.07 62 40 12.66 TR scattered clouds
# Processing Record 47 of Set 13 | kutum
# 14.2 24.6667 82.56 27 90 9.48 SD overcast clouds
# Processing Record 48 of Set 13 | evinayong
# 1.4368 10.5512 68.07 100 100 1.23 GQ moderate rain
# Processing Record 49 of Set 13 | vicuna
# -30.0319 -70.7081 56.93 59 73 6.08 CL broken clouds
# Processing Record 50 of Set 13 | qui nhon
# 13.7667 109.2333 77.16 90 100 6.08 VN overcast clouds
# Processing Record 1 of Set 14 | sinnamary
# 5.3833 -52.95 80.96 79 4 11.97 GF clear sky
# Processing Record 2 of Set 14 | kundiawa
# -6.0167 144.9667 62.85 94 100 2.42 PG overcast clouds
# Processing Record 3 of Set 14 | maxixe
# -23.8597 35.3472 70.95 91 0 9.04 MZ clear sky
# Processing Record 4 of Set 14 | misratah
# 32.3754 15.0925 74.84 60 40 14.5 LY scattered clouds
# Processing Record 5 of Set 14 | dickinson
# 29.4608 -95.0513 89.1 48 20 8.05 US few clouds
# Processing Record 6 of Set 14 | aksu
# 41.1231 80.2644 57.58 29 91 3.47 CN overcast clouds
# Processing Record 7 of Set 14 | rovnoye
# 50.7765 46.0509 53.44 70 52 7.67 RU broken clouds
# Processing Record 8 of Set 14 | sampues
# 9.1836 -75.3817 81.36 83 100 5.26 CO overcast clouds
# Processing Record 9 of Set 14 | newark
# 40.7357 -74.1724 62.91 90 100 8.05 US haze
# Processing Record 10 of Set 14 | juneau
# 58.3019 -134.4197 56.1 94 100 5.75 US overcast clouds
# Processing Record 11 of Set 14 | namatanai
# -3.6667 152.4333 81.34 78 98 8.7 PG overcast clouds
# Processing Record 12 of Set 14 | kopavogur
# 64.1123 -21.913 43.02 75 75 16.11 IS broken clouds
# Processing Record 13 of Set 14 | canela
# -29.3656 -50.8156 60.06 76 92 3.38 BR overcast clouds
# Processing Record 14 of Set 14 | orotukan
# 62.2667 151.7 14.22 96 100 4.83 RU light snow
# Processing Record 15 of Set 14 | camana
# -16.6228 -72.7111 62.8 73 77 10.65 PE broken clouds
# Processing Record 16 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 17 of Set 14 | biltine
# 14.5333 20.9167 88.48 23 47 2.71 TD scattered clouds
# Processing Record 18 of Set 14 | porto empedocle
# 37.2934 13.5264 69.8 80 39 1.79 IT scattered clouds
# Processing Record 19 of Set 14 | santa rosa
# 14.3122 121.1114 80.58 87 100 6.69 PH overcast clouds
# Processing Record 20 of Set 14 | ambilobe
# -13.2 49.05 68.25 80 1 3.6 MG clear sky
# Processing Record 21 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 14 | wendo
# 6.6 38.4167 56.5 92 64 4.85 ET broken clouds
# Processing Record 23 of Set 14 | kibre mengist
# 5.8833 38.9833 57.88 97 97 2.66 ET light rain
# Processing Record 24 of Set 14 | ankang
# 32.68 109.0172 47.35 96 100 2.93 CN overcast clouds
# Processing Record 25 of Set 14 | sorong
# -0.8833 131.25 79 82 22 2.82 ID few clouds
# Processing Record 26 of Set 14 | bengkulu
# -3.8004 102.2655 75.96 84 100 3.69 ID moderate rain
# Processing Record 27 of Set 14 | shelburne
# 44.0787 -80.2041 74.75 43 22 8.99 CA few clouds
# Processing Record 28 of Set 14 | maldonado
# -34.6667 -54.9167 70.23 67 65 14.54 UY broken clouds
# Processing Record 29 of Set 14 | dolores
# -36.3132 -57.6792 62.98 59 100 9.75 AR overcast clouds
# Processing Record 30 of Set 14 | wolsztyn
# 52.1155 16.1171 59.92 65 76 9.48 PL broken clouds
# Processing Record 31 of Set 14 | urfa
# City not found. Skipping...
# Processing Record 32 of Set 14 | linhares
# -19.3911 -40.0722 74.62 82 35 7.4 BR scattered clouds
# Processing Record 33 of Set 14 | vokhma
# 58.9303 46.7586 43.52 98 94 3.87 RU overcast clouds
# Processing Record 34 of Set 14 | shunyi
# 40.125 116.6453 37.35 100 0 2.24 CN clear sky
# Processing Record 35 of Set 14 | fare
# -16.7 -151.0167 78.17 72 12 26.35 PF light rain
# Processing Record 36 of Set 14 | centralia
# 46.7162 -122.9543 60.85 45 27 6.24 US scattered clouds
# Processing Record 37 of Set 14 | iroquois falls
# 48.7669 -80.6831 64.76 72 61 11.39 CA broken clouds
# Processing Record 38 of Set 14 | yangcun
# 39.3639 117.0603 46.38 59 95 2.48 CN overcast clouds
# Processing Record 39 of Set 14 | camacha
# 33.0833 -16.3333 67.42 64 40 11.5 PT scattered clouds
# Processing Record 40 of Set 14 | kaluga
# 54.5 35.5 41.34 97 91 8.55 RU overcast clouds
# Processing Record 41 of Set 14 | severnyy
# 50.677 36.5532 46.44 87 75 6.71 RU broken clouds
# Processing Record 42 of Set 14 | mildura
# -34.2 142.15 59.07 100 100 10.36 AU overcast clouds
# Processing Record 43 of Set 14 | temiscaming
# 46.7212 -79.0971 72.91 46 57 5.75 CA broken clouds
# Processing Record 44 of Set 14 | chagoda
# 59.164 35.3285 42.03 96 96 4 RU overcast clouds
# Processing Record 45 of Set 14 | upington
# -28.4478 21.2561 66.58 18 69 2.3 ZA broken clouds
# Processing Record 46 of Set 14 | nago
# 26.5881 127.9761 77.45 83 33 9.53 JP scattered clouds
# Processing Record 47 of Set 14 | yurimaguas
# -5.9 -76.0833 95.16 49 20 4.61 PE few clouds
# Processing Record 48 of Set 14 | coahuayana
# 18.7333 -103.6833 86.34 68 13 5.77 MX few clouds
# Processing Record 49 of Set 14 | saravan
# 39.7196 45.6483 58.57 41 76 6.6 AM broken clouds
# Processing Record 50 of Set 14 | champerico
# 14.3 -91.9167 93.74 73 100 4.85 GT overcast clouds
# Processing Record 1 of Set 15 | kiato
# 38.0167 22.75 66 44 0 1.01 GR clear sky
# Processing Record 2 of Set 15 | eyl
# 7.9803 49.8164 77.5 82 100 16.06 SO overcast clouds
# Processing Record 3 of Set 15 | vilhena
# -12.7406 -60.1458 84.42 58 40 11.5 BR scattered clouds
# Processing Record 4 of Set 15 | oranjestad
# 12.524 -70.027 87.75 75 40 11.5 AW scattered clouds
# Processing Record 5 of Set 15 | caucaia
# -3.7361 -38.6531 82.35 75 20 12.66 BR few clouds
# Processing Record 6 of Set 15 | vanimo
# -2.6741 141.3028 77.85 90 100 6.04 PG overcast clouds
# Processing Record 7 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 8 of Set 15 | lososina
# 48.9975 140.3106 36.93 53 96 13.58 RU overcast clouds
# Processing Record 9 of Set 15 | jaisalmer
# 26.9147 70.9181 84.94 28 0 9.37 IN clear sky
# Processing Record 10 of Set 15 | sawakin
# 19.1059 37.3321 84.67 55 0 6.17 SD clear sky
# Processing Record 11 of Set 15 | oulainen
# 64.2667 24.8 46.81 98 100 9.69 FI overcast clouds
# Processing Record 12 of Set 15 | kaputa
# -8.4689 29.6619 75.78 38 3 2.39 ZM clear sky
# Processing Record 13 of Set 15 | palmar de varela
# 10.7406 -74.7544 78.91 83 75 5.75 CO broken clouds
# Processing Record 14 of Set 15 | bucerias
# 20.75 -105.3333 87.98 66 40 8.05 MX scattered clouds
# Processing Record 15 of Set 15 | diamantino
# -14.4086 -56.4461 88.03 46 98 6.44 BR overcast clouds
# Processing Record 16 of Set 15 | gasa
# 31.5 34.4667 69.87 72 0 5.97 PS clear sky
# Processing Record 17 of Set 15 | nanortalik
# 60.1432 -45.2371 37.81 87 55 13.73 GL broken clouds
# Processing Record 18 of Set 15 | oschersleben
# 52.0333 11.25 62.02 66 31 12.75 DE scattered clouds
# Processing Record 19 of Set 15 | paso de los toros
# -32.8167 -56.5167 66.25 68 54 10.36 UY light rain
# Processing Record 20 of Set 15 | belyy yar
# 53.6039 91.3903 39.09 81 0 6.71 RU clear sky
# Processing Record 21 of Set 15 | boa vista
# 2.8197 -60.6733 89.58 48 75 5.75 BR thunderstorm
# Processing Record 22 of Set 15 | dongying
# 37.4564 118.4856 50 52 5 2.08 CN clear sky
# Processing Record 23 of Set 15 | chitrakonda
# 18.1167 82.0833 71.92 95 100 2.82 IN light rain
# Processing Record 24 of Set 15 | yueyang
# 29.3333 113.0919 50.23 87 100 11.39 CN overcast clouds
# Processing Record 25 of Set 15 | palmas bellas
# 9.2319 -80.0867 82.35 83 100 5.57 PA overcast clouds
# Processing Record 26 of Set 15 | deniliquin
# -35.5333 144.9667 56.28 90 100 12.1 AU overcast clouds
# Processing Record 27 of Set 15 | basco
# 20.4487 121.9702 82.65 77 26 17.22 PH scattered clouds
# Processing Record 28 of Set 15 | trairi
# -3.2778 -39.2689 78.51 81 44 12.57 BR scattered clouds
# Processing Record 29 of Set 15 | east wenatchee bench
# 47.4257 -120.2812 87.58 38 100 0 US haze
# Processing Record 30 of Set 15 | clyde river
# 70.4692 -68.5914 26.83 74 100 21.85 CA overcast clouds
# Processing Record 31 of Set 15 | maracaju
# -21.6144 -55.1683 87.62 49 51 6.15 BR broken clouds
# Processing Record 32 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 15 | brae
# 60.3964 -1.353 51.28 81 90 27.34 GB light rain
# Processing Record 34 of Set 15 | chodavaram
# 17.8333 82.95 78.64 96 100 2.77 IN overcast clouds
# Processing Record 35 of Set 15 | erenhot
# 43.6475 111.9767 39.99 23 100 6.33 CN overcast clouds
# Processing Record 36 of Set 15 | luis correia
# -2.8792 -41.6669 84.2 74 0 17.27 BR clear sky
# Processing Record 37 of Set 15 | kulunda
# 52.566 78.9385 46.2 78 97 7.99 RU overcast clouds
# Processing Record 38 of Set 15 | haljala
# 59.4336 26.2614 53.08 96 100 10.33 EE overcast clouds
# Processing Record 39 of Set 15 | filadelfia
# 39.9523 -75.1638 62.87 86 100 9.22 US overcast clouds
# Processing Record 40 of Set 15 | pitiquito
# 30.7 -112.0833 89.8 30 0 4.07 MX clear sky
# Processing Record 41 of Set 15 | isangel
# -19.55 169.2667 75.34 69 31 10.67 VU scattered clouds
# Processing Record 42 of Set 15 | platanos
# 37.6667 21.6167 67.08 69 10 4.29 GR clear sky
# Processing Record 43 of Set 15 | shingu
# 33.7333 135.9833 64.26 76 100 5.1 JP overcast clouds
# Processing Record 44 of Set 15 | nemuro
# 43.3236 145.575 50.22 71 100 7.56 JP overcast clouds
# Processing Record 45 of Set 15 | libourne
# 44.9167 -0.25 61.3 95 0 5.1 FR clear sky
# Processing Record 46 of Set 15 | deputatskiy
# 69.3 139.9 8.83 93 100 6.11 RU overcast clouds
# Processing Record 47 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 15 | keflavik
# 64.0049 -22.5624 43.23 75 75 9.22 IS broken clouds
# Processing Record 49 of Set 15 | lompoc
# 34.6391 -120.4579 91.78 69 20 5.75 US few clouds
# Processing Record 50 of Set 15 | mana
# 5.6592 -53.7767 80.94 78 37 11.56 GF scattered clouds
# Processing Record 1 of Set 16 | itarema
# -2.9248 -39.9167 78.51 81 36 17.16 BR scattered clouds
# Processing Record 2 of Set 16 | lac-megantic
# 45.5834 -70.8823 61.59 60 11 1.72 CA few clouds
# Processing Record 3 of Set 16 | zabaykalsk
# 49.6333 117.3167 24.85 59 59 4.92 RU broken clouds
# Processing Record 4 of Set 16 | sisimiut
# 66.9395 -53.6735 30.27 79 32 6.13 GL scattered clouds
# Processing Record 5 of Set 16 | yanliang
# 34.6592 109.2292 45.59 84 100 2.93 CN light rain
# Processing Record 6 of Set 16 | killybegs
# 54.6333 -8.45 53.15 75 54 22.08 IE broken clouds
# Processing Record 7 of Set 16 | zhmerynka
# 49.037 28.112 49.53 68 100 6.53 UA overcast clouds
# Processing Record 8 of Set 16 | coalinga
# 36.1397 -120.3602 88.05 30 0 3.38 US clear sky
# Processing Record 9 of Set 16 | arlit
# 18.7369 7.3853 94.24 14 8 15.86 NE clear sky
# Processing Record 10 of Set 16 | mugur-aksy
# 50.35 90.5 29.57 75 65 6.13 RU broken clouds
# Processing Record 11 of Set 16 | tazmalt
# 36.3868 4.3989 67.28 75 73 2.21 DZ light rain
# Processing Record 12 of Set 16 | porto novo
# 6.4965 2.6036 78.62 87 35 6.11 BJ scattered clouds
# Processing Record 13 of Set 16 | clarksville
# 36.5298 -87.3595 80.65 20 0 5.75 US clear sky
# Processing Record 14 of Set 16 | srandakan
# -7.9386 110.2506 75.94 86 100 8.55 ID overcast clouds
# Processing Record 15 of Set 16 | phan thiet
# 10.9333 108.1 77.47 87 99 4.25 VN overcast clouds
# Processing Record 16 of Set 16 | bud
# 39.447 -86.1758 78.75 30 61 3.33 US broken clouds
# Processing Record 17 of Set 16 | aripuana
# -9.1667 -60.6333 94.48 35 99 0.69 BR overcast clouds
# Processing Record 18 of Set 16 | anadyr
# 64.75 177.4833 43.3 93 75 26.84 RU broken clouds
# Processing Record 19 of Set 16 | cosio
# 22.35 -102.3 68.49 46 95 2.77 MX overcast clouds
# Processing Record 20 of Set 16 | jagdalpur
# 19.0667 82.0333 70.54 95 100 3.33 IN overcast clouds
# Processing Record 21 of Set 16 | baruun-urt
# 46.6806 113.2792 25.54 48 13 7.18 MN few clouds
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have

len(city_data)
# Out:
# 702

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     71.46        78         100
# 1           Chaman  30.9236   66.4512     68.90        12           0
# 2         Tasiilaq  65.6145  -37.6368     32.16        62          72
# 3          Mataura -46.1927  168.8643     39.47        89         100
# 4          Rikitea -23.1203 -134.9692     69.01        64           0
# 5     Longyearbyen  78.2186   15.6401     40.84        70          40
# 6     Punta Arenas -53.1500  -70.9167     53.71        43          75
# 7    Sao Francisco -15.9486  -44.8644     90.16        35          58
# 8            Paris  48.8534    2.3488     61.77        86         100
# 9           Laredo  27.5064  -99.5075     84.49        48         100
#
#    Wind Speed Country Current Description
# 0        9.22      BR     overcast clouds
# 1        5.32      PK           clear sky
# 2        5.26      GL       broken clouds
# 3        8.08      NZ     overcast clouds
# 4       22.28      PF           clear sky
# 5       13.80      SJ    scattered clouds
# 6       14.97      CL       broken clouds
# 7        4.72      BR          light rain
# 8       10.36      FR     overcast clouds
# 9        3.44      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     71.46        78         100
# 1           Chaman  30.9236   66.4512     68.90        12           0
# 2         Tasiilaq  65.6145  -37.6368     32.16        62          72
# 3          Mataura -46.1927  168.8643     39.47        89         100
# 4          Rikitea -23.1203 -134.9692     69.01        64           0
#
#    Wind Speed Country Current Description
# 0        9.22      BR     overcast clouds
# 1        5.32      PK           clear sky
# 2        5.26      GL       broken clouds
# 3        8.08      NZ     overcast clouds
# 4       22.28      PF           clear sky

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order

city_data_df = city_data_df[new_column_order]
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        78         100
# 1           Chaman      PK  30.9236   66.4512     68.90        12           0
# 2         Tasiilaq      GL  65.6145  -37.6368     32.16        62          72
# 3          Mataura      NZ -46.1927  168.8643     39.47        89         100
# 4          Rikitea      PF -23.1203 -134.9692     69.01        64           0
# 5     Longyearbyen      SJ  78.2186   15.6401     40.84        70          40
# 6     Punta Arenas      CL -53.1500  -70.9167     53.71        43          75
# 7    Sao Francisco      BR -15.9486  -44.8644     90.16        35          58
# 8            Paris      FR  48.8534    2.3488     61.77        86         100
# 9           Laredo      US  27.5064  -99.5075     84.49        48         100
#
#    Wind Speed Current Description
# 0        9.22     overcast clouds
# 1        5.32           clear sky
# 2        5.26       broken clouds
# 3        8.08     overcast clouds
# 4       22.28           clear sky
# 5       13.80    scattered clouds
# 6       14.97       broken clouds
# 7        4.72          light rain
# 8       10.36     overcast clouds
# 9        3.44     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
